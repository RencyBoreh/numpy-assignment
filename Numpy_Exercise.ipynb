# %%
#Create Arrays:
#Create an array of 10 random integers between 0 and 50.
#Create a 3x3 identity matrix
import numpy as np
arr=np.array([10,20,30,40,15,25,35,45,32,21])
array2=np.array([[[1,2,4,5],[5,6,7,8],[3,4,5,6]]])
print(arr)
print(array2)
# Out:
# [10 20 30 40 15 25 35 45 32 21]
# [[[1 2 4 5]
#   [5 6 7 8]
#   [3 4 5 6]]]

# %%
array1=np.eye(3)
array1
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#Array Properties:
#Find the shape, size, and data type of the array you created.
print(arr.shape)
print(array2.shape)
print(arr.size)
print(array2.size)
print(arr.dtype)
print(array2.dtype)
# Out:
# (10,)
# (1, 2, 4)
# 10
# 8
# int64
# int64

# %%
print(array2.shape)
# Out:
# (1, 2, 4)

# %%
arr.size
# Out:
# 10

# %%
array2.size
# Out:
# 8

# %%
print(type(array2))
# Out:
# <class 'numpy.ndarray'>

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
array2.dtype
# Out:
# dtype('int64')

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
#Array Manipulation:
#Reshape the array to a 2x5 array.
#Flatten the 2x5 array back to a 1-dimensional array.
array2=array2.reshape(2,-1)
print(array2)
array3=array2.reshape(-1)
print(array3)
# Out:
# [[1 2 4 5 5 6]
#  [7 8 3 4 5 6]]
# [1 2 4 5 5 6 7 8 3 4 5 6]

# %%
#Array Arithmetic:
#Create two arrays of the same shape and perform element-wise addition, subtraction, multiplication, and division.
#Calculate the dot product of two 2x3 matrices.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Data Preparation
temperatures = np.random.randint(15, 35, size=30)  # Random temperatures between 15°C and 35°C

# Step 2: Data Analysis
average_temp = np.mean(temperatures)
max_temp = np.max(temperatures)
min_temp = np.min(temperatures)
days_above_avg = np.sum(temperatures > average_temp)

print(f"Average Temperature: {average_temp:.2f}°C")
print(f"Highest Temperature: {max_temp}°C")
print(f"Lowest Temperature: {min_temp}°C")
print(f"Days Above Average Temperature: {days_above_avg}")

# Step 3: Data Visualization (Optional)
plt.plot(temperatures, marker='o', label='Daily Temperatures')
plt.axhline(y=average_temp, color='r', linestyle='-', label='Average Temperature')
plt.scatter(np.argmax(temperatures), max_temp, color='g', label='Max Temperature')
plt.scatter(np.argmin(temperatures), min_temp, color='b', label='Min Temperature')
plt.xlabel('Day')
plt.ylabel('Temperature (°C)')
plt.title('Daily Temperatures for a Month')
plt.legend()
plt.show()
# Out:
# Average Temperature: 25.03°C
# Highest Temperature: 34°C
# Lowest Temperature: 16°C
# Days Above Average Temperature: 14
